# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
dataset = pd.read_csv("HousingData.csv")
dataset
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030   0.0  2.5050    1  273
#
#      PTRATIO       B  LSTAT  Price
# 0       15.3  396.90   4.98   24.0
# 1       17.8  396.90   9.14   21.6
# 2       17.8  392.83   4.03   34.7
# 3       18.7  394.63   2.94   33.4
# 4       18.7  396.90   0.00   36.2
# ..       ...     ...    ...    ...
# 501     21.0  391.99   0.00   22.4
# 502     21.0  396.90   9.08   20.6
# 503     21.0  396.90   5.64   23.9
# 504     21.0  393.45   6.48   22.0
# 505     21.0  396.90   7.88   11.9
#
# [506 rows x 14 columns]

# %%
dataset.shape
# Out:
# (506, 14)

# %%
dataset.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         B  LSTAT  Price
# 0  396.90   4.98   24.0
# 1  396.90   9.14   21.6
# 2  392.83   4.03   34.7
# 3  394.63   2.94   33.4
# 4  396.90   0.00   36.2

# %%
dataset.tail()
# Out:
#         CRIM   ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 501  0.06263  0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273     21.0
# 502  0.04527  0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273     21.0
# 503  0.06076  0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273     21.0
# 504  0.10959  0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273     21.0
# 505  0.04741  0.0  11.93     0  0.573  6.030   0.0  2.5050    1  273     21.0
#
#           B  LSTAT  Price
# 501  391.99   0.00   22.4
# 502  396.90   9.08   20.6
# 503  396.90   5.64   23.9
# 504  393.45   6.48   22.0
# 505  396.90   7.88   11.9

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     506 non-null    float64
#  1   ZN       506 non-null    float64
#  2   INDUS    506 non-null    float64
#  3   CHAS     506 non-null    int64
#  4   NOX      506 non-null    float64
#  5   RM       506 non-null    float64
#  6   AGE      506 non-null    float64
#  7   DIS      506 non-null    float64
#  8   RAD      506 non-null    int64
#  9   TAX      506 non-null    int64
#  10  PTRATIO  506 non-null    float64
#  11  B        506 non-null    float64
#  12  LSTAT    506 non-null    float64
#  13  Price    506 non-null    float64
# dtypes: float64(11), int64(3)
# memory usage: 55.5 KB

# %%
dataset.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.469112   10.768775   10.645889    0.067194    0.554695    6.284634
# std      8.574755   23.025124    7.039321    0.250605    0.115878    0.702617
# min      0.000000    0.000000    0.000000    0.000000    0.385000    3.561000
# 25%      0.068907    0.000000    4.877500    0.000000    0.449000    5.885500
# 50%      0.224635    0.000000    8.560000    0.000000    0.538000    6.208500
# 75%      2.808720    0.000000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    65.810277    3.795043    9.549407  408.237154   18.455534  356.674032
# std     30.520606    2.105710    8.707259  168.537116    2.164946   91.294864
# min      0.000000    1.129600    1.000000  187.000000   12.600000    0.320000
# 25%     40.425000    2.100175    4.000000  279.000000   17.400000  375.377500
# 50%     74.450000    3.207450    5.000000  330.000000   19.050000  391.440000
# 75%     93.575000    5.188425   24.000000  666.000000   20.200000  396.225000
# max    100.000000   12.126500   24.000000  711.000000   22.000000  396.900000
#
#             LSTAT       Price
# count  506.000000  506.000000
# mean    12.212846   22.532806
# std      7.438324    9.197104
# min      0.000000    5.000000
# 25%      6.590000   17.025000
# 50%     10.925000   21.200000
# 75%     16.570000   25.000000
# max     37.970000   50.000000

# %%
dataset.isnull().sum()
# Out:
# CRIM       0
# ZN         0
# INDUS      0
# CHAS       0
# NOX        0
# RM         0
# AGE        0
# DIS        0
# RAD        0
# TAX        0
# PTRATIO    0
# B          0
# LSTAT      0
# Price      0
# dtype: int64

# %%
type(dataset)
# Out:
# pandas.core.frame.DataFrame

# %%
data = pd.DataFrame()

# %%
data.isnull().sum()
# Out:
# Series([], dtype: float64)

# %%
import seaborn as sns
sns.distplot(dataset.Price)
# Out:
# <Axes: xlabel='Price', ylabel='Density'>

# %%
sns.boxplot(dataset.Price)
# Out:
# <Axes: ylabel='Price'>

# %%
correlation = dataset.corr()
correlation.loc['Price']
# Out:
# CRIM      -0.384120
# ZN         0.362292
# INDUS     -0.441371
# CHAS       0.183844
# NOX       -0.427321
# RM         0.695360
# AGE       -0.356699
# DIS        0.249929
# RAD       -0.381626
# TAX       -0.468536
# PTRATIO   -0.507787
# B          0.333461
# LSTAT     -0.695405
# Price      1.000000
# Name: Price, dtype: float64

# %%
ig,axes = plt.subplots(figsize=(15,12))
sns.heatmap(correlation,square = True, annot=True)
# Out:
# <Axes: >

# %%
plt.figure(figsize=(20,5))
features = ['LSTAT','RM','PTRATIO']
for i,col in enumerate(features):
    plt.subplot(1,len(features),i+1)
    x=dataset[col]
    y=dataset.Price
    plt.scatter(x,y,marker='o')
    plt.title("Variation in House Prices")
    plt.xlabel(col)
    plt.ylabel("House Prices in $1000")

# %%
X = dataset.iloc[:,:-1]
y= dataset.Price

# %%
dataset.columns
# Out:
# Index(['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX',
#        'PTRATIO', 'B', 'LSTAT', 'Price'],
#       dtype='object')

# %%
dataset.dtypes
# Out:
# CRIM       float64
# ZN         float64
# INDUS      float64
# CHAS         int64
# NOX        float64
# RM         float64
# AGE        float64
# DIS        float64
# RAD          int64
# TAX          int64
# PTRATIO    float64
# B          float64
# LSTAT      float64
# Price      float64
# dtype: object

# %%
dataset.isnull().sum()
# Out:
# CRIM       0
# ZN         0
# INDUS      0
# CHAS       0
# NOX        0
# RM         0
# AGE        0
# DIS        0
# RAD        0
# TAX        0
# PTRATIO    0
# B          0
# LSTAT      0
# Price      0
# dtype: int64

# %%
dataset.keys()
# Out:
# Index(['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX',
#        'PTRATIO', 'B', 'LSTAT', 'Price'],
#       dtype='object')

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,r2_score

X = dataset.iloc[:,:-1]
y= dataset.Price


from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=0)

mean = x_train.mean(axis=0)
std = x_train.std(axis=0)
x_train = (x_train - mean) / std
x_test = (x_test - mean) / std

print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (404, 13)
# (102, 13)
# (404,)
# (102,)

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()

# %%
sns.set(rc={'figure.figsize':(11.7,8.27)})
sns.distplot(dataset['Price'], bins=30)
plt.show()

# %%
x = pd.DataFrame(np.c_[dataset['LSTAT'], dataset['RM']], columns=['LSTAT', 'RM'])
y = dataset['Price']

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=0)

print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (404, 2)
# (102, 2)
# (404,)
# (102,)

# %%
plt.figure(figsize=(20,5))
features=['LSTAT','RM']
target=dataset['Price']
for i,col in enumerate(features):
    plt.subplot(1,len(features),i+1)
    x=dataset[col]
    y=target
    plt.scatter(x,y,marker='o')
    plt.title(col)
    plt.xlabel(col)
    plt.ylabel('Price')

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,r2_score
lin_model = LinearRegression()
lin_model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_train_predict=lin_model.predict(x_train)
rmse=(np.sqrt(mean_squared_error(y_train,y_train_predict)))
r2=r2_score(y_train,y_train_predict)
print("The model performace for Training")
print('RMSE is{}',format(rmse))
print('R2 score is{}',format(r2))
print("\n")
# Out:
# The model performace for Training
# RMSE is{} 5.654786516455893
# R2 score is{} 0.624439589170513

# %%
y_test_predict=lin_model.predict(x_test)
rmse=(np.sqrt(mean_squared_error(y_test, y_test_predict)))
r2=r2_score(y_test, y_test_predict)
print("The model performace for Testing")
print(" ")
print('RMSE is{}',format(rmse))
print('R2 score is{}',format(r2))
print("\n")
# Out:
# The model performace for Testing
#
# RMSE is{} 6.05148299416687
# R2 score is{} 0.5502744882429449

# %%
plt.scatter(y_test,y_test_predict)
plt.show()

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
x_train = sc.fit_transform(x_train)
x_test = sc.transform(x_test)

# %%
import keras
from keras.layers import Dense, Activation,Dropout
from keras.models import Sequential
model = Sequential()
model.add(Dense(128,activation = 'relu',input_dim =13))
model.add(Dense(64,activation = 'relu' ))
model.add(Dense(32,activation = 'relu'))
model.add(Dense(16,activation = 'relu'))
model.add(Dense(1))
model.compile(optimizer='adam', loss='mse', metrics=['mae'])
model.compile(optimizer = 'adam',loss ='mean_squared_error',metrics=['mae'])

# %%
# !pip install graphviz
# Out:
# Requirement already satisfied: graphviz in /usr/local/lib/python3.10/dist-packages (0.20.3)

# %%
# !pip install ann_visualizer
# Out:
# Collecting ann_visualizer
#   Downloading ann_visualizer-2.5.tar.gz (4.7 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: ann_visualizer
#   Building wheel for ann_visualizer (setup.py) ... done
#   Created wheel for ann_visualizer: filename=ann_visualizer-2.5-py3-none-any.whl size=4168 sha256=fb0b03d30978cc9a2e5d764917b7685c7abbddf17fb2a77bf1299f8241a6f2d8
#   Stored in directory: /root/.cache/pip/wheels/6e/0f/ae/f5dba91db71b1b32bf03d0ad18c32e86126093aba5ec6b6488
# Successfully built ann_visualizer
# Installing collected packages: ann_visualizer
# Successfully installed ann_visualizer-2.5

# %%
from ann_visualizer.visualize import ann_viz

# %%
import keras
from keras.layers import Dense, Activation,Dropout
from keras.models import Sequential
model = Sequential()
model.add(Dense(128,activation = 'relu', input_shape=(x_train[0].shape)))
model.add(Dense(64,activation = 'relu'))
model.add(Dense(32,activation = 'relu'))
model.add(Dense(16,activation = 'relu'))
model.add(Dense(1))

# %%
x_train[0]
# Out:
# array([-0.32442717,  0.93567804])

# %%
k=4
num_epochs=100
num_samples=len(x_train)
all_scores=[]
model.compile(optimizer='adam', loss='mse', metrics=['mae'])
history = model.fit(x_train, y_train,epochs= num_epochs,verbose=1,batch_size=1,validation_data=(x_test,y_test))
# Out:
# Epoch 1/100
# 404/404 [==============================] - 2s 3ms/step - loss: 144.5564 - mae: 8.3009 - val_loss: 38.4726 - val_mae: 4.0098
# Epoch 2/100
# 404/404 [==============================] - 1s 3ms/step - loss: 29.1760 - mae: 3.9303 - val_loss: 28.4081 - val_mae: 3.2807
# Epoch 3/100
# 404/404 [==============================] - 1s 3ms/step - loss: 25.4892 - mae: 3.5706 - val_loss: 29.6443 - val_mae: 3.1746
# Epoch 4/100
# 404/404 [==============================] - 2s 4ms/step - loss: 23.2231 - mae: 3.3379 - val_loss: 28.6925 - val_mae: 3.3511
# Epoch 5/100
# 404/404 [==============================] - 2s 4ms/step - loss: 23.2384 - mae: 3.3365 - val_loss: 27.7075 - val_mae: 3.1378
# Epoch 6/100
# 404/404 [==============================] - 1s 3ms/step - loss: 24.2992 - mae: 3.3506 - val_loss: 28.4513 - val_mae: 3.2225
# Epoch 7/100
# 404/404 [==============================] - 1s 3ms/step - loss: 21.9048 - mae: 3.1810 - val_loss: 28.3474 - val_mae: 3.1634
# Epoch 8/100
# 404/404 [==============================] - 1s 2ms/step - loss: 21.3469 - mae: 3.1966 - val_loss: 32.7449 - val_mae: 3.7298
# Epoch 9/100
# 404/404 [==============================] - 1s 2ms/step - loss: 21.5518 - mae: 3.2518 - val_loss: 28.9999 - val_mae: 3.1569
# Epoch 10/100
# 404/404 [==============================] - 1s 2ms/step - loss: 22.7668 - mae: 3.2442 - val_loss: 33.9123 - val_mae: 3.5420
# Epoch 11/100
# 404/404 [==============================] - 1s 3ms/step - loss: 22.2188 - mae: 3.1006 - val_loss: 28.4797 - val_mae: 3.1102
# Epoch 12/100
# 404/404 [==============================] - 1s 2ms/step - loss: 20.8141 - mae: 3.1404 - val_loss: 31.2225 - val_mae: 3.3066
# Epoch 13/100
# 404/404 [==============================] - 1s 3ms/step - loss: 20.9173 - mae: 3.1888 - val_loss: 33.8988 - val_mae: 3.5238
# Epoch 14/100
# 404/404 [==============================] - 1s 2ms/step - loss: 21.2959 - mae: 3.0853 - val_loss: 31.2440 - val_mae: 3.3161
# Epoch 15/100
# 404/404 [==============================] - 1s 3ms/step - loss: 21.0295 - mae: 3.1539 - val_loss: 30.2491 - val_mae: 3.3874
# Epoch 16/100
# 404/404 [==============================] - 2s 4ms/step - loss: 21.4663 - mae: 3.0762 - val_loss: 30.1780 - val_mae: 3.2190
# Epoch 17/100
# 404/404 [==============================] - 1s 3ms/step - loss: 19.8157 - mae: 3.1025 - val_loss: 29.3889 - val_mae: 3.4141
# Epoch 18/100
# 404/404 [==============================] - 1s 3ms/step - loss: 20.4965 - mae: 3.1367 - val_loss: 30.9584 - val_mae: 3.2505
# Epoch 19/100
# 404/404 [==============================] - 1s 3ms/step - loss: 21.0053 - mae: 3.1813 - val_loss: 29.2856 - val_mae: 3.1709
# Epoch 20/100
# 404/404 [==============================] - 1s 2ms/step - loss: 20.8572 - mae: 3.1801 - val_loss: 30.0698 - val_mae: 3.2279
# Epoch 21/100
# 404/404 [==============================] - 1s 2ms/step - loss: 18.8422 - mae: 2.9892 - val_loss: 42.4741 - val_mae: 4.2242
# Epoch 22/100
# 404/404 [==============================] - 1s 2ms/step - loss: 17.9239 - mae: 3.0130 - val_loss: 29.3956 - val_mae: 3.2193
# Epoch 84/100
# 404/404 [==============================] - 1s 2ms/step - loss: 16.9197 - mae: 2.8925 - val_loss: 32.0328 - val_mae: 3.3022
# Epoch 85/100
# 404/404 [==============================] - 1s 2ms/step - loss: 16.9594 - mae: 2.9168 - val_loss: 30.8025 - val_mae: 3.4601
# Epoch 86/100
# 404/404 [==============================] - 1s 3ms/step - loss: 16.4009 - mae: 2.9456 - val_loss: 31.1665 - val_mae: 3.5359
# Epoch 87/100
# 404/404 [==============================] - 2s 4ms/step - loss: 17.8368 - mae: 2.9841 - val_loss: 37.6074 - val_mae: 4.3903
# Epoch 88/100
# 404/404 [==============================] - 1s 4ms/step - loss: 17.6406 - mae: 2.9357 - val_loss: 29.3469 - val_mae: 3.2234
# Epoch 89/100
# 404/404 [==============================] - 1s 2ms/step - loss: 16.9874 - mae: 2.9533 - val_loss: 30.8209 - val_mae: 3.2228
# Epoch 90/100
# 404/404 [==============================] - 1s 3ms/step - loss: 17.7261 - mae: 3.0260 - val_loss: 31.7053 - val_mae: 3.6837
# Epoch 91/100
# 404/404 [==============================] - 1s 2ms/step - loss: 16.5247 - mae: 2.9412 - val_loss: 29.5279 - val_mae: 3.2163
# Epoch 92/100
# 404/404 [==============================] - 1s 2ms/step - loss: 17.6625 - mae: 2.9992 - val_loss: 29.7176 - val_mae: 3.4471
# Epoch 93/100
# 404/404 [==============================] - 1s 2ms/step - loss: 16.4028 - mae: 2.9535 - val_loss: 30.5165 - val_mae: 3.1635
# Epoch 94/100
# 404/404 [==============================] - 1s 2ms/step - loss: 17.7013 - mae: 2.9633 - val_loss: 40.2933 - val_mae: 4.1038
# Epoch 95/100
# 404/404 [==============================] - 1s 2ms/step - loss: 17.2362 - mae: 2.9942 - val_loss: 29.2955 - val_mae: 3.2608
# Epoch 96/100
# 404/404 [==============================] - 1s 2ms/step - loss: 18.0962 - mae: 2.9515 - val_loss: 30.1128 - val_mae: 3.6028
# Epoch 97/100
# 404/404 [==============================] - 1s 3ms/step - loss: 16.8421 - mae: 2.9454 - val_loss: 31.1420 - val_mae: 3.7170
# Epoch 98/100
# 404/404 [==============================] - 1s 3ms/step - loss: 16.8040 - mae: 2.9622 - val_loss: 33.2781 - val_mae: 3.4013
# Epoch 99/100
# 404/404 [==============================] - 2s 4ms/step - loss: 17.1841 - mae: 3.0230 - val_loss: 28.5609 - val_mae: 3.1588
# Epoch 100/100
# 404/404 [==============================] - 1s 3ms/step - loss: 16.2337 - mae: 2.8138 - val_loss: 32.6048 - val_mae: 3.7474

# %%
from plotly.subplots import make_subplots
import plotly.graph_objects as go
fig = go.Figure()
fig.add_trace(go.Scattergl(y=history.history['loss'], name='Train'))
fig.add_trace(go.Scattergl(y=history.history['val_loss'], name='Valid'))
fig.update_layout(height=500, width=700, xaxis_title='Epoch', yaxis_title='Loss')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="db6712a1-cda4-4321-9925-b6ba22c12b59" class="plotly-graph-div" style="height:500px; width:700px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("
805,3.2638304233551025,3.610264301300049,3.20297908782959,3.2717344760894775,3.195222854614258,3.322084426879883,3.2093307971954346,3.494094133377075,3.406050682067871,3.2549684047698975,3.422992467880249,3.4734206199645996,3.214857816696167,3.313584327697754,3.6446900367736816,3.592946767807007,3.3140718936920166,3.1806349754333496,3.3577911853790283,3.398388147354126,3.623836040496826,3.2122507095336914,3.224693775177002,3.3241496086120605,3.514481544494629,3.243476152420044,3.314204216003418,3.9079225063323975,3.3992364406585693,3.3268938064575195,3.43660831451416,3.2192537784576416 ...

# %%
y_pred = model.predict(x_test)
mse_nn, mae_nn = model.evaluate(x_test, y_test)
print('Mean squared error on test data: ', mse_nn)
print('Mean absolute error on test data: ', mae_nn)
# Out:
# 4/4 [==============================] - 0s 6ms/step
# 4/4 [==============================] - 0s 5ms/step - loss: 32.6048 - mae: 3.7474
# Mean squared error on test data:  32.60483932495117
# Mean absolute error on test data:  3.7474257946014404

# %%
from sklearn.metrics import mean_absolute_error
lr_model = LinearRegression()
lr_model.fit(x_train, y_train)
y_pred_lr = lr_model.predict(x_test)
mse_lr = mean_squared_error(y_test, y_pred_lr)
mae_lr = mean_absolute_error(y_test, y_pred_lr)
print('Mean squared error on test data: ', mse_lr)
print('Mean absolute error on test data: ', mae_lr)
from sklearn.metrics import r2_score
r2 = r2_score(y_test, y_pred)
print(r2)
# Out:
# Mean squared error on test data:  36.62044642869082
# Mean absolute error on test data:  3.9628859404678494
# 0.5995890385253746

# %%
from sklearn.metrics import mean_squared_error
rmse = (np.sqrt(mean_squared_error(y_test, y_pred)))
print(rmse)
# Out:
# 5.710064761117253

# %%
y_test_predict=lin_model.predict(x_test)

# %%
y_test_predict
# Out:
# array([ -7.55227652,  -8.70320313,  -7.43254349, -16.81246391,
#         -8.76358367, -11.88592594, -11.4892784 , -10.80086074,
#        -19.51891925,  -7.16881369, -11.68814145,  -5.76191163,
#         -8.21593125, -23.35113224,   5.35211227,  -1.33372687,
#         -8.56626732,   0.80990989,  -5.59545322, -11.77051921,
#         -6.74954692, -11.74305037,  -9.78138211,  -6.27138652,
#        -13.30374943, -29.0311836 , -11.1443968 , -13.46433948,
#          7.46819398, -10.28989895,  -9.56280689, -10.21630265,
#         -8.66136396,  -9.93585767,  -6.96367162, -12.58234869,
#        -11.86307309, -11.56507122,  -8.14574353, -10.18401759,
#         -9.39549055, -12.69297489,  -9.28626505, -16.0332736 ,
#         -5.87912508,  -6.92804473, -12.77722935,  -9.83646578,
#        -21.28182318,  -4.33867631,  -9.63336263, -13.92361923,
#        -10.85530385,   9.13507103, -13.16154085, -11.92404366,
#        -13.25460088, -11.63440332, -12.65729053, -11.42794676,
#        -11.41199867,  -9.80549984,  -1.84516931,  -5.4343422 ,
#        -13.35809938,  -5.45626573,  -5.53454244,  -8.09528513,
#         -3.99847744, -11.56802325,  -8.3369454 ,  -8.06505755,
#         -7.73190481,  -2.74847644,  -4.02491824, -20.64388803,
#          9.00404391,  -7.86618523,  -6.93903755, -12.62126457,
#         -5.2267598 ,  -7.02837382, -13.21962382,   9.15273268,
#         13.03188287,  -7.64798267,  -9.2818479 , -12.36599873,
#         -6.04666345, -10.75642597, -11.8688381 ,  -6.14421292,
#         -9.41671604,  -2.87630542, -10.17349523,  -9.59810609,
#        -28.41217034,  -7.01601832,  -6.67094575, -13.00661338,
#         -7.3370524 ,  -6.69537171])

# %%
from google.colab import drive
drive.mount('/content/drive')
